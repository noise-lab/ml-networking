# %% [markdown]
# # Machine Learning for Network Security

# %% [markdown]
# #### Load Normal and Attack Traffic

# %%
# load library
import pandas as pd

# normal traffic
nfile = 'data/csv/Friday-WorkingHours-Morning.pcap_ISCX.csv.gz'

# attack traffic
afile = 'data/csv/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv.gz'


# load data
n = pd.read_csv(nfile)
a = pd.read_csv(afile)

# %%
n.head(2)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0               3268       112740690                  32
# 1                389       112740560                  32
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       16                         6448
# 1                       16                         6448
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          1152                     403
# 1                          5056                     403
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                    201.5              204.724205
# 1                       0                    201.5              204.724205
#
#     ...     min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0   ...                       32   359.428571    11.998016          380
# ...

# %%
a.head(2)
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22         1266342                  41
# 1                 22         1319353                  41
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       44                         2664
# 1                       44                         2664
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          6954                     456
# 1                          6954                     456
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       0                 64.97561              109.864573
# 1                       0                 64.97561              109.864573
#
#     ...     min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0   ...                       32          0.0          0.0            0
# ...

# %%
n.iloc[0]
# Out:
#  Destination Port                      3268
#  Flow Duration                    112740690
#  Total Fwd Packets                       32
#  Total Backward Packets                  16
# Total Length of Fwd Packets            6448
#  Total Length of Bwd Packets           1152
#  Fwd Packet Length Max                  403
#  Fwd Packet Length Min                    0
#  Fwd Packet Length Mean               201.5
#  Fwd Packet Length Std              204.724
# Bwd Packet Length Max                    72
#  Bwd Packet Length Min                   72
#  Bwd Packet Length Mean                  72
#  Bwd Packet Length Std                    0
# Flow Bytes/s                    67.41133126
#  Flow Packets/s                 0.425755776
#  Flow IAT Mean                  2.39874e+06
#  Flow IAT Std                    5.7987e+06
#  Flow IAT Max                      16400000
#  Flow IAT Min                             3
# Fwd IAT Total                     113000000
# ...

# %%
a.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      286467.000000    2.864670e+05       286467.000000
# mean         8044.876324    5.379331e+06            3.473283
# std         15378.583442    2.192364e+07           19.515131
# min             0.000000   -1.300000e+01            1.000000
# 25%            80.000000    4.400000e+01            1.000000
# 50%          1110.000000    6.500000e+01            1.000000
# 75%          6881.000000    2.380600e+04            2.000000
# max         65389.000000    1.199999e+08         3119.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            286467.000000                286467.000000
# mean                  3.520500                   233.407667
# std                  28.288916                  1865.523600
# min                   0.000000                     0.000000
# 25%                   1.000000                     0.000000
# ...

# %%
n.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      191033.000000    1.910330e+05       191033.000000
# mean         6756.069988    1.164499e+07           13.826548
# std         16697.438823    3.070084e+07         1097.755533
# min             0.000000   -1.200000e+01            1.000000
# 25%            53.000000    1.940000e+02            2.000000
# 50%            80.000000    3.112100e+04            2.000000
# 75%           443.000000    4.102840e+05            4.000000
# max         64948.000000    1.200000e+08       207964.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            191033.000000                 1.910330e+05
# mean                 16.413714                 5.999468e+02
# std                1479.792387                 7.924198e+03
# min                   0.000000                 0.000000e+00
# 25%                   1.000000                 4.000000e+01
# ...

# %% [markdown]
# ### Assignment for Project

# %% [markdown]
# Develop a classifier that can distinguish normal traffic from attack traffic based on feature sets.
#
# 1. Take mean statistics for each column in each dataset.
# 2. Identify columns where the means are sufficiently different between normal and attack traffic.
# 3. Pick a classifier to train based on one or more features.
# 4. Train and evaluate.

# %%
a.keys()
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
a[' Flow Duration'].iloc[0:10]
# Out:
# 0    1266342
# 1    1319353
# 2        160
# 3    1303488
# 4         77
# 5        244
# 6    1307239
# 7         82
# 8        171
# 9        210
# Name:  Flow Duration, dtype: int64

# %%
print(a[ ' Flow Duration'].mean())
print(a[ ' Flow Duration'].median())
# Out:
# 5379330.607438204
# 65.0

# %%
print(n[ ' Flow Duration'].mean())
print(n[ ' Flow Duration'].median())
# Out:
# 11644985.209822387
# 31121.0

# %%
ndur.shape[0]
# Out:
# 191033

# %% [markdown]
# Hint: For the normal traffic, the flows are much longer. So, use that to develop a classifier, say based on logistic regression, that uses flow duration as the feature and normal/attack as the target.

# %%
ndur = n[' Flow Duration']
adur = a[' Flow Duration']

# %%
features = pd.concat([ndur,adur])

# %%
import numpy as np
targets = pd.concat([
    pd.DataFrame(np.zeros(adur.shape[0])),
    pd.DataFrame(np.ones(ndur.shape[0]))
])

# %%
targets.shape
# Out:
# (477500, 1)

# %%
features.shape
# Out:
# (477500,)

# %% [markdown]
# Features and Targets are now each in a dataframe of same size.  You can train the logistic regression model using features and targets exactly as is done in the code in that notebook.
