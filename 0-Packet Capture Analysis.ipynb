# %%
from data_collection.parse_pcap import pcap_to_pandas, send_rates
from datetime import datetime, timezone
from pandas import DataFrame

# %% [markdown]
# ## Load a Packet Capture into Pandas

# %%
pcap = pcap_to_pandas('/Users/feamster/Downloads/example-20200314.pcap') # this can take a few minutes
pcap.head(n=4)
# Out:
#                     datetime dns_query dns_resp        ip_dst    ip_dst_int  \
# 0 2020-03-14 20:17:15.939347      None     None  192.168.1.13  3.232236e+09
# 1 2020-03-14 20:17:15.939351      None     None  192.168.1.13  3.232236e+09
# 2 2020-03-14 20:17:15.939353      None     None  192.168.1.13  3.232236e+09
# 3 2020-03-14 20:17:15.939354      None     None  192.168.1.13  3.232236e+09
#
#            ip_src    ip_src_int  is_dns  length            mac_dst  \
# 0  162.255.36.123  2.734630e+09   False     883  3c:15:c2:d9:d3:50
# 1  162.255.36.123  2.734630e+09   False     494  3c:15:c2:d9:d3:50
# 2  162.255.36.123  2.734630e+09   False     525  3c:15:c2:d9:d3:50
# 3  162.255.36.123  2.734630e+09   False     292  3c:15:c2:d9:d3:50
#
#       mac_dst_int            mac_src    mac_src_int  port_dst  port_src  \
# 0  66064161035088  08:02:8e:92:27:27  8807074899751   63010.0    8801.0
# 1  66064161035088  08:02:8e:92:27:27  8807074899751   63010.0    8801.0
# 2  66064161035088  08:02:8e:92:27:27  8807074899751   63010.0    8801.0
# 3  66064161035088  08:02:8e:92:27:27  8807074899751   63010.0    8801.0
#
#   protocol          time  time_normed
# 0      UDP  1.584235e+09     0.000000
# 1      UDP  1.584235e+09     0.000004
# 2      UDP  1.584235e+09     0.000006
# 3      UDP  1.584235e+09     0.000007

# %%
pcap.shape
# Out:
# (3365, 18)

# %%
pcap[pcap['ip_src'] == '192.168.1.13'].head(2)
# Out:
#                      datetime dns_query dns_resp          ip_dst  \
# 15 2020-03-14 20:17:15.962859      None     None  162.255.36.123
# 43 2020-03-14 20:17:16.062898      None     None  162.255.36.123
#
#       ip_dst_int        ip_src    ip_src_int  is_dns  length  \
# 15  2.734630e+09  192.168.1.13  3.232236e+09   False      99
# 43  2.734630e+09  192.168.1.13  3.232236e+09   False      99
#
#               mac_dst    mac_dst_int            mac_src     mac_src_int  \
# 15  08:02:8e:92:27:27  8807074899751  3c:15:c2:d9:d3:50  66064161035088
# 43  08:02:8e:92:27:27  8807074899751  3c:15:c2:d9:d3:50  66064161035088
#
#     port_dst  port_src protocol          time  time_normed
# 15    8801.0   58575.0      UDP  1.584235e+09     0.023512
# 43    8801.0   58575.0      UDP  1.584235e+09     0.123551

# %% [markdown]
# **Example:** Create a Dataframe with unique IP addresses.

# %%
unique_dst_ip = DataFrame(pcap['ip_dst'].unique())[0]
print(unique_dst_ip)
# Out:
# 0       192.168.1.13
# 1     162.255.36.123
# 2      172.217.8.174
# 3      17.253.25.203
# 4       157.240.2.53
# 5               None
# 6       172.217.1.46
# 7       34.194.201.2
# 8     74.125.124.189
# 9      35.186.224.53
# 10     18.211.118.21
# 11       192.168.1.1
# 12      199.232.77.7
# 13     17.248.132.59
# 14      172.217.1.42
# 15     23.21.193.169
# 16      96.17.11.144
# 17      172.217.9.74
# Name: 0, dtype: object

# %% [markdown]
# ## Basic Analysis of Traffic Using Pandas

# %% [markdown]
# Define a reverse lookup function.

# %%
from dns import resolver
from dns import reversename

# test reverse DNS lookup
addr = reversename.from_address('34.193.201.2')
print(resolver.query(addr, "PTR")[0])
# Out:
# ec2-34-193-201-2.compute-1.amazonaws.com.

# %%
def reverse_lookup(ip):
    if str(ip) == 'None':
        return 'None'
    addr = reversename.from_address(ip)
    try:
        return str(resolver.query(addr, "PTR")[0])
    except Exception as e:
        return 'N/A'

# %% [markdown]
# Use the pandas 'apply' function to create a new column with the DNS names associated with each destination.
#
# Then look at the unique destination IP addresses in the trace.

# %%
pcap['name_dst'] = pcap['ip_dst'].apply(reverse_lookup)

# %%
unique_dst_name = DataFrame(pcap['name_dst'].unique())[0]
print(unique_dst_name)
# Out:
# 0                                                   N/A
# 1                                 zoomny123mmr.zoom.us.
# 2                            ord37s08-in-f14.1e100.net.
# 3                        uschi5-vip-bx-003.aaplimg.com.
# 4                   whatsapp-cdn-shv-01-ort2.fbcdn.net.
# 5                                                  None
# 6                            ord37s07-in-f46.1e100.net.
# 7                            ord37s07-in-f14.1e100.net.
# 8             ec2-34-194-201-2.compute-1.amazonaws.com.
# 9               53.224.186.35.bc.googleusercontent.com.
# 10           ec2-18-211-118-21.compute-1.amazonaws.com.
# 11                           ord37s07-in-f42.1e100.net.
# 12           ec2-23-21-193-169.compute-1.amazonaws.com.
# 13    a96-17-11-144.deploy.static.akamaitechnologies...
# 14                           ord38s09-in-f10.1e100.net.
# Name: 0, dtype: object

# %% [markdown]
# Write functions to count ("sum") the length field so that we can know how much total traffic in bytes is sent to each destination, either by IP address or by name.

# %%
def volume_stats_by_ip(pcap):
    return pcap.loc[:,['ip_dst','length']].groupby('ip_dst').sum().sort_values(by=['length'], ascending=False)


def volume_stats_by_name(pcap):
    return pcap.loc[:,['name_dst','length']].groupby('name_dst').sum().sort_values(by=['length'], ascending=False)

# %%
volume_stats_by_ip(pcap)
# Out:
#                  length
# ip_dst
# 192.168.1.13    1538859
# 162.255.36.123   250577
# 172.217.1.46       6984
# 17.248.132.59      2648
# 74.125.124.189     2316
# 199.232.77.7       1965
# 172.217.8.174       974
# 35.186.224.53       909
# 17.253.25.203       762
# 18.211.118.21       567
# 96.17.11.144        432
# 34.194.201.2        378
# 157.240.2.53        163
# 192.168.1.1          82
# 172.217.9.74         66
# 172.217.1.42         66
# 23.21.193.169        54

# %%
volume_stats_by_name(pcap)
# Out:
#                                                      length
# name_dst
# N/A                                                 1545870
# zoomny123mmr.zoom.us.                                250577
# ord37s07-in-f14.1e100.net.                             4718
# ord37s07-in-f46.1e100.net.                             2266
# ord37s08-in-f14.1e100.net.                              974
# 53.224.186.35.bc.googleusercontent.com.                 909
# uschi5-vip-bx-003.aaplimg.com.                          762
# ec2-18-211-118-21.compute-1.amazonaws.com.              567
# a96-17-11-144.deploy.static.akamaitechnologies....      432
# ec2-34-194-201-2.compute-1.amazonaws.com.               378
# whatsapp-cdn-shv-01-ort2.fbcdn.net.                     163
# None                                                     84
# ord37s07-in-f42.1e100.net.                               66
# ord38s09-in-f10.1e100.net.                               66
# ec2-23-21-193-169.compute-1.amazonaws.com.               54
